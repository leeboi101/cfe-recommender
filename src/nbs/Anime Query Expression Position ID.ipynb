# %%
import setup_django
setup_django.init()
# Out:
# PWD environment variable is not set. Setting it to: ..

# %%
from anime.models import Anime

qs = Anime.objects.all().order_by('id')[:100]

# %%
for i, obj in enumerate(qs):
    print("position:", i, "\t\tid:", obj.id, '\t\tdelta:', obj.id - i)
# Out:
# position: 0 		id: 1 		delta: 1
# position: 1 		id: 2 		delta: 1
# position: 2 		id: 3 		delta: 1
# position: 3 		id: 4 		delta: 1
# position: 4 		id: 5 		delta: 1
# position: 5 		id: 6 		delta: 1
# position: 6 		id: 7 		delta: 1
# position: 7 		id: 8 		delta: 1
# position: 8 		id: 9 		delta: 1
# position: 9 		id: 10 		delta: 1
# position: 10 		id: 11 		delta: 1
# position: 11 		id: 12 		delta: 1
# position: 12 		id: 13 		delta: 1
# position: 13 		id: 14 		delta: 1
# position: 14 		id: 15 		delta: 1
# position: 15 		id: 16 		delta: 1
# position: 16 		id: 17 		delta: 1
# position: 17 		id: 18 		delta: 1
# position: 18 		id: 19 		delta: 1
# position: 19 		id: 20 		delta: 1
# position: 20 		id: 21 		delta: 1
# position: 21 		id: 22 		delta: 1
# position: 22 		id: 23 		delta: 1
# position: 23 		id: 24 		delta: 1
# position: 24 		id: 25 		delta: 1
# position: 25 		id: 26 		delta: 1
# position: 26 		id: 27 		delta: 1
# position: 27 		id: 28 		delta: 1
# position: 28 		id: 29 		delta: 1
# ...

# %%
from django.db.models import Window, F
from django.db.models.functions import DenseRank

# %%
qs = Anime.objects.all().annotate(
        new_idx=Window(
            expression=DenseRank(),
            order_by=[F('id').asc()]
        )
    ).annotate(final_idx = F('new_idx') - 1
    
    )

for i, obj in enumerate(qs[:100]):
    print("position:", i, "\t\tidx:", obj.final_idx, '\t\tdelta:', obj.final_idx - i)
# Out:
# position: 0 		idx: 0 		delta: 0
# position: 1 		idx: 1 		delta: 0
# position: 2 		idx: 2 		delta: 0
# position: 3 		idx: 3 		delta: 0
# position: 4 		idx: 4 		delta: 0
# position: 5 		idx: 5 		delta: 0
# position: 6 		idx: 6 		delta: 0
# position: 7 		idx: 7 		delta: 0
# position: 8 		idx: 8 		delta: 0
# position: 9 		idx: 9 		delta: 0
# position: 10 		idx: 10 		delta: 0
# position: 11 		idx: 11 		delta: 0
# position: 12 		idx: 12 		delta: 0
# position: 13 		idx: 13 		delta: 0
# position: 14 		idx: 14 		delta: 0
# position: 15 		idx: 15 		delta: 0
# position: 16 		idx: 16 		delta: 0
# position: 17 		idx: 17 		delta: 0
# position: 18 		idx: 18 		delta: 0
# position: 19 		idx: 19 		delta: 0
# position: 20 		idx: 20 		delta: 0
# position: 21 		idx: 21 		delta: 0
# position: 22 		idx: 22 		delta: 0
# position: 23 		idx: 23 		delta: 0
# position: 24 		idx: 24 		delta: 0
# position: 25 		idx: 25 		delta: 0
# position: 26 		idx: 26 		delta: 0
# position: 27 		idx: 27 		delta: 0
# ...
